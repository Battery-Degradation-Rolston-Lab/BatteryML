# %%
import pickle

# Load predictions from the pickle file
with open('C:\\Users\\harshitha\\Desktop\\batteryml\\BatteryML-main\\BatteryML-main\\workspaces\\baselines\\sklearn\\pcr\\matr_1\\predictions_seed_0_20240611074156.pkl', 'rb') as f:
    predictions = pickle.load(f)

# %%
print(predictions)

# %%
import matplotlib.pyplot as plt

predictions = [2.6060, 2.7070, 2.2328, 0.2872, 1.2852, 0.9453, 1.2174, -0.1836, -0.2516, 1.1995, 1.2225, 0.7472, 0.5618, 0.3613, 0.1461, 0.5082, 0.0559, -0.3879, 1.0915, -0.1771, -1.0282, -1.9564, -0.2289, -0.1484, -0.7705, -0.6251, -0.7095, 0.1239, -0.4049, 0.1380, -1.1721, -0.0948, -0.3290, -0.4695, -0.5606, -0.2773, -0.4220, -0.3683, -0.6302, -1.0988, -1.1546, 0.7005]

fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Histogram of Predictions
axs[0].hist(predictions, bins=10, color='blue', alpha=0.7)
axs[0].set_xlabel('Predictions')
axs[0].set_ylabel('Frequency')
axs[0].set_title('Histogram of Predictions')

# Scatter Plot of Predictions vs. Index
axs[1].scatter(range(len(predictions)), predictions, color='green', alpha=0.7)
axs[1].set_xlabel('Index')
axs[1].set_ylabel('Predictions')
axs[1].set_title('Scatter Plot of Predictions vs. Index')

# Box Plot of Predictions
axs[2].boxplot(predictions, vert=False)
axs[2].set_xlabel('Predictions')
axs[2].set_title('Box Plot of Predictions')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the predicted RUL values
predicted_rul = [2.6060, 2.7070, 2.2328, 0.2872, 1.2852, 0.9453, 1.2174, -0.1836, -0.2516, 1.1995, 1.2225, 0.7472, 0.5618, 
                 0.3613, 0.1461, 0.5082, 0.0559, -0.3879, 1.0915, -0.1771, -1.0282, -1.9564, -0.2289, -0.1484, -0.7705, 
                 -0.6251, -0.7095, 0.1239, -0.4049, 0.1380, -1.1721, -0.0948, -0.3290, -0.4695, -0.5606, -0.2773, -0.4220, 
                 -0.3683, -0.6302, -1.0988, -1.1546, 0.7005]

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(range(1, len(predicted_rul) + 1), predicted_rul, color='blue', label='Predicted RUL')
plt.xlabel('Battery Instance')
plt.ylabel('Predicted RUL')
plt.title('Predicted Remaining Useful Life (RUL)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pickle

# Load predictions from the pickle file
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\workspaces\baselines\sklearn\discharge_model\matr_1\predictions_seed_0_20240611103410.pkl', 'rb') as f:
    predictions = pickle.load(f)

# %%
print(predictions)

# %%
import pickle

# Load the pickle file
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\processed_data\MATR_b1c0.pkl', 'rb') as f:
    data = pickle.load(f)

# Get the keys (which represent the features)
features = list(data.keys())

# Display the features
print("Features:")
for feature in features:
    print(feature)
print(type(cycle_data))

# %%
import pickle
import matplotlib.pyplot as plt

# Load the predictions
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\workspaces\baselines\sklearn\discharge_model\matr_1\predictions_seed_0_20240611103410.pkl', 'rb') as f:
    predictions = pickle.load(f)

# Load the dataset
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\processed_data\MATR_b1c0.pkl', 'rb') as f:
    data = pickle.load(f)

# Extract the 'cycle_data' feature from the dataset
cycle_data = data['cycle_data']

# Convert any dictionaries in cycle_data to strings
cycle_data = [str(entry) if isinstance(entry, dict) else entry for entry in cycle_data]

# Plot a line graph
plt.plot(cycle_data, predictions, marker='o', linestyle='-')
plt.xlabel('Cycle Data')
plt.ylabel('Predictions')
plt.title('Predictions vs Cycle Data')
plt.grid(True)
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt

# Load the predictions
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\workspaces\baselines\sklearn\discharge_model\matr_1\predictions_seed_0_20240611103410.pkl', 'rb') as f:
    predictions = pickle.load(f)

# Load the dataset
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\processed_data\MATR_b1c0.pkl', 'rb') as f:
    data = pickle.load(f)

# Extract the 'cycle_data' feature from the dataset if it exists
cycle_data = data.get('cycle_data')

# Check if 'cycle_data' exists in the dataset and is not None
if cycle_data is not None:
    # Convert any dictionaries in cycle_data to strings
    cycle_data = [str(entry) if isinstance(entry, dict) else entry for entry in cycle_data]

    # Plot a subset of the data
    subset_size = 100  # Adjust this value to change the number of points plotted
    plt.plot(cycle_data[:subset_size], predictions[:subset_size], marker='o', linestyle='-')
    plt.xlabel('Cycle Data')
    plt.ylabel('Predictions')
    plt.title('Predictions vs Cycle Data (Subset)')
    plt.grid(True)
    plt.show()
else:
    print("The 'cycle_data' feature does not exist in the dataset or is None.")

# %%
import pickle
import matplotlib.pyplot as plt

# Load the predictions
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\workspaces\baselines\sklearn\discharge_model\matr_1\predictions_seed_0_20240611103410.pkl', 'rb') as f:
    predictions = pickle.load(f)

# Load the dataset
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\processed_data\MATR_b1c0.pkl', 'rb') as f:
    data = pickle.load(f)

# Extract the 'cycle_data' feature from the dataset if it exists
cycle_data = data.get('cycle_data')

# Check if 'cycle_data' exists in the dataset and is not None
if cycle_data is not None:
    # Convert any dictionaries in cycle_data to strings
    cycle_data = [str(entry) if isinstance(entry, dict) else entry for entry in cycle_data]

    # Plot a subset of the data
    subset_size = 100  # Adjust this value to change the number of points plotted
    plt.plot(cycle_data[:subset_size], predictions[:subset_size], marker='o', linestyle='-')
    plt.xlabel('Cycle Data')
    plt.ylabel('Predictions')
    plt.title('Predictions vs Cycle Data (Subset)')
    plt.grid(True)
    plt.show()
else:
    print("The 'cycle_data' feature does not exist in the dataset or is None.")

# %%
import pickle
import matplotlib.pyplot as plt

# Load the predictions
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\workspaces\baselines\sklearn\discharge_model\matr_1\predictions_seed_0_20240611103410.pkl', 'rb') as f:
    predictions = pickle.load(f)

# Load the dataset
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\processed_data\MATR_b1c0.pkl', 'rb') as f:
    data = pickle.load(f)

# Extract the 'cycle_data' feature from the dataset if it exists
cycle_data = data.get('cycle_data')

# Check if 'cycle_data' exists in the dataset and is not None
if cycle_data is not None:
    # Convert any dictionaries in cycle_data to strings
    cycle_data = [str(entry) if isinstance(entry, dict) else entry for entry in cycle_data]

    # Plot a subset of the data
    subset_size = 100  # Adjust this value to change the number of points plotted
    plt.plot(cycle_data[:subset_size], predictions[:subset_size], marker='o', linestyle='-')
    plt.xlabel('Cycle Data')
    plt.ylabel('Predictions')
    plt.title('Predictions vs Cycle Data (Subset)')
    plt.grid(True)
    plt.show()
else:
    print("The 'cycle_data' feature does not exist in the dataset or is None.")

# %%
cycle_numbers = [int(data.split(',')[0].split(': ')[1]) for data in cycle_data]

print(cycle_numbers)

# %%
import pickle
import matplotlib.pyplot as plt

# Load predictions from the pickle file
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\workspaces\baselines\sklearn\discharge_model\matr_1\predictions_seed_0_20240611103410.pkl', 'rb') as f:
    predictions_data = pickle.load(f)

# Extracting predicted RUL values and cycle numbers
predictions = predictions_data['prediction']
cycle_numbers = range(1, len(predictions) + 1)

# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(cycle_numbers, predictions, marker='o', linestyle='-')
plt.xlabel('Cycle Number')
plt.ylabel('Predicted RUL')
plt.title('Predicted RUL vs. Cycle Number')
plt.grid(True)
plt.show()

# %%
import pickle

# Load predictions from the pickle file
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\workspaces\baselines\sklearn\discharge_model\matr_1\predictions_seed_0_20240611103410.pkl', 'rb') as f:
    predictions_data = pickle.load(f)

# Extracting predicted RUL values
predictions = predictions_data['prediction']

# Load the training dataset to get feature information
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\processed_data\MATR_b1c0.pkl', 'rb') as f:
    data = pickle.load(f)

# Extract the features
features = data.keys()

# Print the type of each feature
for feature in features:
    print(f"Feature: {feature}, Type: {type(data[feature])}")

# %%
import pickle
import matplotlib.pyplot as plt

# Load predictions from the pickle file
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\workspaces\baselines\sklearn\discharge_model\matr_1\predictions_seed_0_20240611103410.pkl', 'rb') as f:
    predictions_data = pickle.load(f)

# Extracting predicted RUL values
predictions = predictions_data.get('prediction')
if predictions is None:
    raise ValueError("Predictions not found in the pickle file.")

# Load the dataset containing features
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\processed_data\MATR_b1c0.pkl', 'rb') as f:
    data = pickle.load(f)

# Function to plot line plots for features
def plot_line_plots(features):
    for feature in features:
        feature_values = data.get(feature)
        if feature_values is None:
            print(f"Feature '{feature}' not found in the dataset.")
            continue
        if len(feature_values) != len(predictions):
            print(f"Length mismatch: Feature '{feature}' has {len(feature_values)} values but there are {len(predictions)} predictions.")
            continue
        plt.figure(figsize=(10, 6))
        plt.plot(feature_values, predictions, marker='o', linestyle='-')
        plt.xlabel(f'{feature}')
        plt.ylabel('Predicted RUL')
        plt.title(f'Predicted RUL vs. {feature}')
        plt.grid(True)
        plt.show()

# Features to plot
all_features = ['cell_id', 'form_factor', 'anode_material', 'cathode_material', 'nominal_capacity_in_Ah', 
                'depth_of_charge', 'depth_of_discharge', 'already_spent_cycles', 'max_voltage_limit_in_V', 
                'min_voltage_limit_in_V']

# Plot line plots for all features
plot_line_plots(all_features)

# %%
import pickle
import matplotlib.pyplot as plt

# Load predictions from the pickle file
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\workspaces\baselines\sklearn\discharge_model\matr_1\predictions_seed_0_20240611103410.pkl', 'rb') as f:
    predictions_data = pickle.load(f)

# Extracting predicted RUL values
predictions = predictions_data.get('prediction')
if predictions is None:
    raise ValueError("Predictions not found in the pickle file.")

# Load the dataset containing features
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\processed_data\MATR_b1c0.pkl', 'rb') as f:
    data = pickle.load(f)

# Function to plot line plots for features
def plot_line_plots(features):
    for feature in features:
        feature_values = data.get(feature)
        if feature_values is None:
            print(f"Feature '{feature}' not found in the dataset.")
            continue
        # Convert single float feature values into lists
        if isinstance(feature_values, float):
            feature_values = [feature_values]
        if len(feature_values) != len(predictions):
            print(f"Length mismatch: Feature '{feature}' has {len(feature_values)} values but there are {len(predictions)} predictions.")
            continue
        plt.figure(figsize=(10, 6))
        plt.plot(feature_values, predictions, marker='o', linestyle='-')
        plt.xlabel(f'{feature}')
        plt.ylabel('Predicted RUL')
        plt.title(f'Predicted RUL vs. {feature}')
        plt.grid(True)
        plt.show()

# Features to plot
all_features = ['cell_id', 'form_factor', 'anode_material', 'cathode_material', 'nominal_capacity_in_Ah', 
                'depth_of_charge', 'depth_of_discharge', 'already_spent_cycles', 'max_voltage_limit_in_V', 
                'min_voltage_limit_in_V']

# Plot line plots for all features
plot_line_plots(all_features)

# %%
import pickle
import matplotlib.pyplot as plt

# Load predictions from the pickle file
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\workspaces\baselines\sklearn\discharge_model\matr_1\predictions_seed_0_20240611103410.pkl', 'rb') as f:
    predictions_data = pickle.load(f)

# Extracting predicted RUL values
predictions = predictions_data.get('prediction')
if predictions is None:
    raise ValueError("Predictions not found in the pickle file.")

# Load the dataset containing features
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\processed_data\MATR_b1c0.pkl', 'rb') as f:
    data = pickle.load(f)

# Extract nominal capacity feature
nominal_capacity = data.get('nominal_capacity_in_Ah')
if nominal_capacity is None:
    raise ValueError("Nominal capacity feature not found in the dataset.")

# Ensure nominal capacity is a list
if not isinstance(nominal_capacity, list):
    nominal_capacity = [nominal_capacity]

# Ensure both nominal capacity and predictions have the same length
if len(nominal_capacity) != len(predictions):
    raise ValueError("Length mismatch: Nominal capacity and predictions must have the same length.")

# Plot nominal capacity vs. predicted RUL
plt.figure(figsize=(10, 6))
plt.plot(nominal_capacity, predictions, marker='o', linestyle='-')
plt.xlabel('Nominal Capacity (Ah)')
plt.ylabel('Predicted RUL')
plt.title('Predicted RUL vs. Nominal Capacity')
plt.grid(True)
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt

# Load the b1c1 dataset
with open(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\processed_data\MATR_b1c1.pkl', 'rb') as f:
    b1c1_data = pickle.load(f)

# Extract cycle data
cycle_data = b1c1_data.get('cycle_data')

# Check the structure of the first cycle in cycle_data

# Assuming we found the correct keys, update these variables accordingly
cycle_number_key = 'cycle_index'  # or the correct key based on the printed structure
discharge_capacity_key = 'discharge_capacity'  # or the correct key based on the printed structure

# Extract cycle numbers and discharge capacities
cycle_numbers = []
discharge_capacities = []

for cycle in cycle_data:
    cycle_number = cycle.get(cycle_number)
    discharge_capacity = cycle.get(discharge_capacity_in_Ah)
    print(discharge_capacity)
    
    if cycle_number is not None and discharge_capacity is not None:
        cycle_numbers.append(cycle_number)
        discharge_capacities.append(discharge_capacity_in_Ah)
print(discharge_capacities, cycle_numbers)

# Plot the discharge capacity against cycle number
plt.figure(figsize=(10, 6))
plt.plot(cycle_numbers, discharge_capacities, marker='o', linestyle='-')
plt.xlabel('Cycle Number')
plt.ylabel('Discharge Capacity')
plt.title('Discharge Capacity vs Cycle Number')
plt.grid(True)
plt.show()

# %%
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result

# %%
pipeline = Pipeline(config_path='configs/baselines/sklearn/discharge_model/matr_1.yaml', workspace='workspaces')

# %%
pipeline.evaluate(checkpoint='C:\\Users\\harshitha\\Desktop\\batteryml\\BatteryML-main\\BatteryML-main\\workspaces\\baselines\\sklearn\\discharge_model\\matr_1\\latest.ckpt')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the pickled file
data = pd.read_pickle(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\processed_data\MATR_b1c1.pkl')

# Extract cycle_data from the dictionary
cycle_data = data['cycle_data']

# Initialize lists to store cycle numbers and discharge capacities
cycle_numbers = []
discharge_capacities = []

# Iterate through each cycle dictionary
for cycle in cycle_data:
    # Extract cycle number and discharge capacity for the current cycle
    cycle_number = cycle['cycle_number']
    discharge_capacity = cycle['discharge_capacity_in_Ah'][-1]  # Taking the last value in the list
    
    # Append to lists
    cycle_numbers.append(cycle_number)
    discharge_capacities.append(discharge_capacity)

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(cycle_numbers, discharge_capacities, marker='o', linestyle='-')

# Add labels and title
plt.xlabel('Cycle Numbers')
plt.ylabel('Discharge Capacity (Ah)')
plt.title('Cycle Numbers vs. Discharge Capacity')

# Show grid
plt.grid(True)

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of dataset filenames with 'MATR_b1c1' prefix
datasets = ['MATR_b1c1.pkl', 'MATR_b1c3.pkl', 'MATR_b1c5.pkl', 'MATR_b1c7.pkl', 'MATR_b1c11.pkl', 'MATR_b1c15.pkl',
            'MATR_b1c17.pkl', 'MATR_b1c19.pkl', 'MATR_b1c21.pkl', 'MATR_b1c24.pkl', 'MATR_b1c26.pkl', 'MATR_b1c28.pkl',
            'MATR_b1c30.pkl', 'MATR_b1c32.pkl', 'MATR_b1c34.pkl', 'MATR_b1c36.pkl', 'MATR_b1c38.pkl', 'MATR_b1c40.pkl',
            'MATR_b1c42.pkl', 'MATR_b1c44.pkl', 'MATR_b2c0.pkl', 'MATR_b2c2.pkl', 'MATR_b2c4.pkl', 'MATR_b2c6.pkl',
            'MATR_b2c11.pkl', 'MATR_b2c13.pkl', 'MATR_b2c17.pkl', 'MATR_b2c19.pkl', 'MATR_b2c21.pkl', 'MATR_b2c23.pkl',
            'MATR_b2c25.pkl', 'MATR_b2c27.pkl', 'MATR_b2c29.pkl', 'MATR_b2c31.pkl', 'MATR_b2c33.pkl', 'MATR_b2c35.pkl',
            'MATR_b2c37.pkl', 'MATR_b2c39.pkl', 'MATR_b2c41.pkl', 'MATR_b2c43.pkl', 'MATR_b2c45.pkl']

# Initialize lists to store cycle numbers and discharge capacities for all datasets
all_cycle_numbers = []
all_discharge_capacities = []

# Iterate through each dataset
for dataset in datasets:
    # Read the pickled file
    data = pd.read_pickle(r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\processed_data\\' + dataset)

    # Extract cycle_data from the dictionary
    cycle_data = data['cycle_data']

    # Initialize lists to store cycle numbers and discharge capacities for the current dataset
    cycle_numbers = []
    discharge_capacities = []

    # Iterate through each cycle dictionary
    for cycle in cycle_data:
        # Extract cycle number and discharge capacity for the current cycle
        cycle_number = cycle['cycle_number']
        discharge_capacity = cycle['discharge_capacity_in_Ah'][-1]  # Taking the last value in the list

        # Append to lists
        cycle_numbers.append(cycle_number)
        discharge_capacities.append(discharge_capacity)

    # Append cycle numbers and discharge capacities for the current dataset to the lists for all datasets
    all_cycle_numbers.append(cycle_numbers)
    all_discharge_capacities.append(discharge_capacities)

# Create the plot
plt.figure(figsize=(10, 8))

# Plot data for each dataset
for i in range(len(datasets)):
    plt.plot(all_cycle_numbers[i], all_discharge_capacities[i], label=datasets[i])

# Add labels and title
plt.xlabel('Cycle Numbers')
plt.ylabel('Discharge Capacity (Ah)')
plt.title('Cycle Numbers vs. Discharge Capacity for Multiple Datasets')
plt.legend()  # Add legend to distinguish datasets

# Show grid
plt.grid(True)

# Show plot
plt.show()

# %%
import pandas as pd

# Load the MATR dataset
dataset_path = r'C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\processed_data\MATR_b1c1.pkl'
data = pd.read_pickle(dataset_path)

# Initialize a dictionary to store parameter counts
parameter_counts = {}

# Iterate through each dictionary in the dataset
for key, value in data.items():
    # If the value is a dictionary, iterate through its items
    if isinstance(value, dict):
        for parameter, values in value.items():
            # Update parameter counts
            parameter_counts[parameter] = parameter_counts.get(parameter, 0) + len(values)

# Print parameter counts
for parameter, count in parameter_counts.items():
    print(f'{parameter}: {count} entries')

# %%
# Import necessary modules
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result

# Create a pipeline with a config file by specifying the config_path and workspace.
# Developers need to modify the data, feature, model and other related settings in the config file in advance.
pipeline = Pipeline(config_path='configs/baselines/sklearn/variance_model/matr_1.yaml', workspace='workspaces')

# Model training. The training process will follow the config file, and the checkpoints will be saved to workspace.
model, dataset = pipeline.train(device='cpu', skip_if_executed=True)

# Evaluate the trained model on the given dataset.
pipeline.evaluate(model=model, dataset=dataset, skip_if_executed=False)

# Generate predictions on the test data.
prediction = model.predict(dataset, data_type='test').to('cpu')

# Extract ground truth labels for the test data.
ground_truth = dataset.test_data.label.to('cpu')

# Plot the results to visualize model performance.
plot_result(ground_truth, prediction)

# %%
# Import necessary modules
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result

# Create a pipeline with a config file by specifying the config_path and workspace.
# Developers need to modify the data, feature, model and other related settings in the config file in advance.
pipeline = Pipeline(config_path='configs/baselines/sklearn/discharge_model/matr_1.yaml', workspace='workspaces')

# Model training. The training process will follow the config file, and the checkpoints will be saved to workspace.
model, dataset = pipeline.train(device='cpu', skip_if_executed=False)

# Evaluate the trained model on the given dataset.
pipeline.evaluate(model=model, dataset=dataset, skip_if_executed=False)

# Generate predictions on the test data.
prediction = model.predict(dataset, data_type='test').to('cpu')

# Extract ground truth labels for the test data.
ground_truth = dataset.test_data.label.to('cpu')

# Plot the results to visualize model performance.
plot_result(ground_truth, prediction)

# %%
# Import necessary modules
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result

# Create a pipeline with a config file by specifying the config_path and workspace.
# Developers need to modify the data, feature, model and other related settings in the config file in advance.
pipeline = Pipeline(config_path='configs/baselines/sklearn/variance_model/matr_1.yaml', workspace='workspaces')

# Model training. The training process will follow the config file, and the checkpoints will be saved to workspace.
model, dataset = pipeline.train(device='cpu', skip_if_executed=False)

# Evaluate the trained model on the given dataset.
pipeline.evaluate(model=model, dataset=dataset, skip_if_executed=False)

# Generate predictions on the test data.
prediction = model.predict(dataset, data_type='test').to('cpu')

# Extract ground truth labels for the test data.
ground_truth = dataset.test_data.label.to('cpu')

# Plot the results to visualize model performance.
plot_result(ground_truth, prediction)

# %%
# Import necessary modules
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result

# Create a pipeline with a config file by specifying the config_path and workspace.
# Developers need to modify the data, feature, model and other related settings in the config file in advance.
pipeline = Pipeline(config_path='configs/baselines/sklearn/discharge_model/matr_1.yaml', workspace='workspaces')

# Model training. The training process will follow the config file, and the checkpoints will be saved to workspace.
model, dataset = pipeline.train(device='cpu', skip_if_executed=False)

# Evaluate the trained model on the given dataset.
pipeline.evaluate(model=model, dataset=dataset, skip_if_executed=False)

# Generate predictions on the test data.
prediction = model.predict(dataset, data_type='test').to('cpu')

# Extract ground truth labels for the test data.
ground_truth = dataset.test_data.label.to('cpu')

# Plot the results to visualize model performance.
plot_result(ground_truth, prediction)

# %%
# Import necessary modules
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result

# Create a pipeline with a config file by specifying the config_path and workspace.
# Developers need to modify the data, feature, model and other related settings in the config file in advance.
pipeline = Pipeline(config_path='configs/baselines/sklearn/discharge_model/matr_1.yaml', workspace='workspaces')

# Model training. The training process will follow the config file, and the checkpoints will be saved to workspace.
model, dataset = pipeline.train(device='cpu', skip_if_executed=False)

# Evaluate the trained model on the given dataset.
pipeline.evaluate(model=model, dataset=dataset, skip_if_executed=False)

# Generate predictions on the test data.
prediction = model.predict(dataset, data_type='test').to('cpu')

# Extract ground truth labels for the test data.
ground_truth = dataset.test_data.label.to('cpu')

# Plot the results to visualize model performance.
plot_result(ground_truth, prediction)

# %%
from batteryml.builders import MODELS
from batteryml.models.sklearn_model import SklearnModel
from sklearn.linear_model import LinearRegression

@MODELS.register()
class LinearRegressionSOHPredictor(SklearnModel):
    def __init__(self, *args, workspace: str = None, **kwargs):
        super().__init__(workspace)
        self.model = LinearRegression(*args, **kwargs)

# %%
# Import necessary modules
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result

# Create a pipeline with a config file by specifying the config_path and workspace.
# Developers need to modify the data, feature, model and other related settings in the config file in advance.
pipeline = Pipeline(config_path='configs/baselines/sklearn/discharge_model/mix.yaml', workspace='workspaces')

# Model training. The training process will follow the config file, and the checkpoints will be saved to workspace.
model, dataset = pipeline.train(device='cpu', skip_if_executed=False)

# Evaluate the trained model on the given dataset.
pipeline.evaluate(model=model, dataset=dataset, skip_if_executed=False)

# Generate predictions on the test data.
prediction = model.predict(dataset, data_type='test').to('cpu')

# Extract ground truth labels for the test data.
ground_truth = dataset.test_data.label.to('cpu')

# Plot the results to visualize model performance.
plot_result(ground_truth, prediction)

# %%
# Import necessary modules
import pandas as pd
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result

# Create a pipeline with a config file by specifying the config_path and workspace.
# Developers need to modify the data, feature, model and other related settings in the config file in advance.
pipeline = Pipeline(config_path='configs/baselines/sklearn/variance_model/matr_1.yaml', workspace='workspaces')

# Model training. The training process will follow the config file, and the checkpoints will be saved to workspace.
model, dataset = pipeline.train(device='cpu', skip_if_executed=False)

# Evaluate the trained model on the given dataset.
pipeline.evaluate(model=model, dataset=dataset, skip_if_executed=False)

# Generate predictions on the test data.
prediction = model.predict(dataset, data_type='test').to('cpu')

# Extract ground truth labels for the test data.
ground_truth = dataset.test_data.label.to('cpu')

# Convert predictions and ground truth to pandas DataFrame
results_df = pd.DataFrame({
    'Ground Truth': ground_truth.numpy(),
    'Predicted': prediction.numpy()
})

# Export predictions to an Excel file
excel_filename = 'predictions_with_ground_truth.xlsx'
results_df.to_excel(excel_filename, index=False)

# Plot the results to visualize model performance.
plot_result(ground_truth, prediction)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file, skipping the first 98 rows and using row 99 as the header
file_path = 'C:\\Users\\harshitha\\Desktop\\batteryml\\BatteryML-main\\BatteryML-main\\Custom data.xlsx'
data = pd.read_excel(file_path, skiprows=98)

# Check the columns in the DataFrame
print(data.columns)

# Update these column names based on the output of the above print statement if they differ
ns_column = 'Ns'
cycle_number_column = 'cycle number'
discharge_capacity_column = 'Q discharge/mA.h'

# List to store data for each cell
cells_data = []

# Extract data for each cell based on 'Ns' column
for cell_num in range(1, 11):
    cell_data = data[data[ns_column] == cell_num]
    cycle_numbers = cell_data[cycle_number_column]
    discharge_capacities = cell_data[discharge_capacity_column]
    cells_data.append((cycle_numbers, discharge_capacities, f'Cell {cell_num}'))

# Plot the data
plt.figure(figsize=(12, 8))

for cycle_numbers, discharge_capacities, cell_name in cells_data:
    plt.plot(cycle_numbers, discharge_capacities, label=cell_name)

plt.xlabel('Cycle Number')
plt.ylabel('Discharge Capacity (mA.h)')
plt.title('Cycle Number vs Discharge Capacity for Each Cell')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file, skipping the first 98 rows and using row 99 as the header
file_path = 'C:\\Users\\harshitha\\Desktop\\batteryml\\BatteryML-main\\BatteryML-main\\Custom data.xlsx'
data = pd.read_excel(file_path, skiprows=98)

# Check the columns in the DataFrame
print(data.columns)

ns_column = 'Ns'
cycle_number_column = 'cycle number'
discharge_capacity_column = 'Q discharge/mA.h'

# List to store data for each cell
cells_data = []

# Extract data for each cell based on 'Ns' column
for cell_num in range(1, 11):
    cell_data = data[data[ns_column] == cell_num]
    cycle_numbers = cell_data[cycle_number_column]
    discharge_capacities = cell_data[discharge_capacity_column] / 1000  # Convert to A.h
    cells_data.append((cycle_numbers, discharge_capacities, f'Cell {cell_num}'))

# Plot the data
plt.figure(figsize=(12, 8))

for cycle_numbers, discharge_capacities, cell_name in cells_data:
    plt.plot(cycle_numbers, discharge_capacities, label=cell_name)

plt.xlabel('Cycle Number')
plt.ylabel('Discharge Capacity (A.h)')
plt.title('Cycle Number vs Discharge Capacity for Each Cell')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file, skipping the first 98 rows and using row 99 as the header
file_path = 'C:\\Users\\harshitha\\Desktop\\batteryml\\BatteryML-main\\BatteryML-main\\Custom data.xlsx'
data = pd.read_excel(file_path, skiprows=98)

# Check the columns in the DataFrame
data.columns = data.columns.str.strip()
print(data.columns)

# Specify the columns of interest
ns_column = 'Ns'
cycle_number_column = 'cycle number'
discharge_capacity_column = 'Q discharge/mA.h'

# Filter out rows with NaN values in critical columns
data = data.dropna(subset=[ns_column, cycle_number_column, discharge_capacity_column])

# Normalize the discharge capacities
max_capacity = data[discharge_capacity_column].max()
data[discharge_capacity_column] = data[discharge_capacity_column] / max_capacity

# List to store data for each cell
cells_data = []

# Extract data for each cell based on 'Ns' column
for cell_num in range(1, 11):
    cell_data = data[data[ns_column] == cell_num]
    cycle_numbers = cell_data[cycle_number_column]
    discharge_capacities = cell_data[discharge_capacity_column] / 1000  # Convert to A.h
    cells_data.append((cycle_numbers, discharge_capacities, f'Cell {cell_num}'))

# Plot the data
plt.figure(figsize=(12, 8))

for cycle_numbers, discharge_capacities, cell_name in cells_data:
    plt.plot(cycle_numbers, discharge_capacities, label=cell_name, marker='o', linestyle='-')

plt.xlabel('Cycle Number')
plt.ylabel('Discharge Capacity (Normalized)')
plt.title('Cycle Number vs Discharge Capacity for Each Cell')
plt.legend()
plt.grid(True)
plt.ylim(0, 1)  # Adjust y-axis limits if needed
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file, skipping the first 98 rows and using row 99 as the header
file_path = 'C:\\Users\\harshitha\\Desktop\\batteryml\\BatteryML-main\\BatteryML-main\\Custom data.xlsx'
data = pd.read_excel(file_path, skiprows=98)

# Check the columns in the DataFrame
data.columns = data.columns.str.strip()
print(data.columns)

# Specify the columns of interest
ns_column = 'Ns'
cycle_number_column = 'cycle number'
discharge_capacity_column = 'Q discharge/mA.h'

# Filter out rows with NaN values in critical columns
data = data.dropna(subset=[ns_column, cycle_number_column, discharge_capacity_column])

# List to store data for each cell
cells_data = []

# Extract data for each cell based on 'Ns' column
for cell_num in range(1, 11):
    cell_data = data[data[ns_column] == cell_num]
    print(f"Cell {cell_num} data:\n", cell_data[[cycle_number_column, discharge_capacity_column]].head())
    cycle_numbers = cell_data[cycle_number_column]
    discharge_capacities = cell_data[discharge_capacity_column] / 1000  # Convert to A.h
    cells_data.append((cycle_numbers, discharge_capacities, f'Cell {cell_num}'))

# Plot the data
plt.figure(figsize=(12, 8))

for cycle_numbers, discharge_capacities, cell_name in cells_data:
    plt.plot(cycle_numbers, discharge_capacities, label=cell_name, marker='o', linestyle='-')

plt.xlabel('Cycle Number')
plt.ylabel('Discharge Capacity (A.h)')
plt.title('Cycle Number vs Discharge Capacity for Each Cell')
plt.legend()
plt.grid(True)
plt.yscale('log')  # Use log scale if necessary
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file, skipping the first 98 rows and using row 99 as the header
file_path = 'C:\\Users\\harshitha\\Desktop\\batteryml\\BatteryML-main\\BatteryML-main\\Custom data.xlsx'
data = pd.read_excel(file_path, skiprows=98)

# Check the columns in the DataFrame
data.columns = data.columns.str.strip()
print(data.columns)

# Specify the columns of interest
ns_column = 'Ns'
cycle_number_column = 'cycle number'
discharge_capacity_column = 'Q discharge/mA.h'

# Filter out rows with NaN values in critical columns
data = data.dropna(subset=[ns_column, cycle_number_column, discharge_capacity_column])

# List to store data for each cell
cells_data = []

# Extract data for each cell based on 'Ns' column
for cell_num in range(1, 11):
    cell_data = data[data[ns_column] == cell_num]
    cycle_numbers = cell_data[cycle_number_column]
    discharge_capacities = cell_data[discharge_capacity_column] / 1000  # Convert to A.h
    cells_data.append((cycle_numbers, discharge_capacities, f'Cell {cell_num}'))

# Plot the data
plt.figure(figsize=(12, 8))

for cycle_numbers, discharge_capacities, cell_name in cells_data:
    plt.plot(cycle_numbers, discharge_capacities, label=cell_name, marker='o', linestyle='-')

plt.xlabel('Cycle Number')
plt.ylabel('Discharge Capacity (A.h)')
plt.title('Cycle Number vs Discharge Capacity for Each Cell')
plt.legend()
plt.grid(True)
plt.ylim(0, max(data[discharge_capacity_column]) / 1000)  # Adjust y-axis limits if needed
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file, skipping the first 98 rows and using row 99 as the header
file_path = 'C:\\Users\\harshitha\\Desktop\\batteryml\\BatteryML-main\\BatteryML-main\\Custom data.xlsx'
data = pd.read_excel(file_path, skiprows=98)

# Check the columns in the DataFrame
data.columns = data.columns.str.strip()
print(data.columns)

# Specify the columns of interest
ns_column = 'Ns'
cycle_number_column = 'cycle number'
discharge_capacity_column = 'Q discharge/mA.h'

# Filter out rows with NaN values in critical columns and rows with zero discharge capacity
data = data.dropna(subset=[ns_column, cycle_number_column, discharge_capacity_column])
data = data[data[discharge_capacity_column] > 0]

# List to store data for each cell
cells_data = []

# Extract data for each cell based on 'Ns' column and calculate average discharge capacity for each cycle
for cell_num in range(1, 11):
    cell_data = data[data[ns_column] == cell_num]
    if not cell_data.empty:
        avg_discharge_per_cycle = cell_data.groupby(cycle_number_column)[discharge_capacity_column].mean() / 1000  # Convert to A.h
        cycle_numbers = avg_discharge_per_cycle.index
        discharge_capacities = avg_discharge_per_cycle.values
        cells_data.append((cycle_numbers, discharge_capacities, f'Cell {cell_num}'))

# Plot the data
plt.figure(figsize=(12, 8))

for cycle_numbers, discharge_capacities, cell_name in cells_data:
    plt.plot(cycle_numbers, discharge_capacities, label=cell_name, marker='o', linestyle='-')

plt.xlabel('Cycle Number')
plt.ylabel('Discharge Capacity (A.h)')
plt.title('Cycle Number vs Average Discharge Capacity for Each Cell')
plt.legend()
plt.grid(True)
plt.ylim(0, max(data[discharge_capacity_column]) / 1000)  # Adjust y-axis limits if needed
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file, skipping the first 98 rows and using row 99 as the header
file_path = 'C:\\Users\\harshitha\\Desktop\\batteryml\\BatteryML-main\\BatteryML-main\\Custom data.xlsx'
data = pd.read_excel(file_path, skiprows=98)

# Check the columns in the DataFrame
data.columns = data.columns.str.strip()
print("Columns in the dataset:", data.columns)

# Specify the columns of interest
ns_column = 'Ns'
cycle_number_column = 'cycle number'
discharge_capacity_column = 'Q discharge/mA.h'

# Filter out rows with NaN values in critical columns and rows with zero discharge capacity
data = data.dropna(subset=[ns_column, cycle_number_column, discharge_capacity_column])
data = data[data[discharge_capacity_column] > 0]

# List to store data for each cell
cells_data = []

# Extract data for each cell based on 'Ns' column and calculate average discharge capacity for each cycle
for cell_num in range(1, 11):
    cell_data = data[data[ns_column] == cell_num]
    if not cell_data.empty:
        print(f"Cell {cell_num} data (first 5 rows):\n", cell_data[[cycle_number_column, discharge_capacity_column]].head())
        avg_discharge_per_cycle = cell_data.groupby(cycle_number_column)[discharge_capacity_column].mean() / 1000  # Convert to A.h
        cycle_numbers = avg_discharge_per_cycle.index
        discharge_capacities = avg_discharge_per_cycle.values
        cells_data.append((cycle_numbers, discharge_capacities, f'Cell {cell_num}'))
    else:
        print(f"Cell {cell_num} has no data")

# Plot the data
plt.figure(figsize=(12, 8))

for cycle_numbers, discharge_capacities, cell_name in cells_data:
    plt.plot(cycle_numbers, discharge_capacities, label=cell_name, marker='o', linestyle='-')

plt.xlabel('Cycle Number')
plt.ylabel('Discharge Capacity (A.h)')
plt.title('Cycle Number vs Average Discharge Capacity for Each Cell')
plt.legend()
plt.grid(True)
plt.ylim(0, max(data[discharge_capacity_column]) / 1000)  # Adjust y-axis limits if needed
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file, skipping the first 98 rows and using row 99 as the header
file_path = 'C:\\Users\\harshitha\\Desktop\\batteryml\\BatteryML-main\\BatteryML-main\\Custom data.xlsx'
data = pd.read_excel(file_path, skiprows=98)

# Check the columns in the DataFrame
data.columns = data.columns.str.strip()
print("Columns in the dataset:", data.columns)

# Specify the columns of interest
ns_column = 'Ns'
cycle_number_column = 'cycle number'
discharge_capacity_column = 'Q discharge/mA.h'

# Print initial rows of the dataset
print("Initial data (first 5 rows):")
print(data.head())

# Filter out rows with NaN values in critical columns and rows with zero discharge capacity
data = data.dropna(subset=[ns_column, cycle_number_column, discharge_capacity_column])
data = data[data[discharge_capacity_column] > 0]

# Print rows after filtering
print("Data after filtering (first 5 rows):")
print(data.head())

# List to store data for each cell
cells_data = []

# Extract data for each cell based on 'Ns' column and calculate average discharge capacity for each cycle
for cell_num in range(1, 11):
    cell_data = data[data[ns_column] == cell_num]
    if not cell_data.empty:
        print(f"Cell {cell_num} data (first 5 rows):\n", cell_data[[cycle_number_column, discharge_capacity_column]].head())
        avg_discharge_per_cycle = cell_data.groupby(cycle_number_column)[discharge_capacity_column].mean() / 1000  # Convert to A.h
        cycle_numbers = avg_discharge_per_cycle.index
        discharge_capacities = avg_discharge_per_cycle.values
        cells_data.append((cycle_numbers, discharge_capacities, f'Cell {cell_num}'))
    else:
        print(f"Cell {cell_num} has no data")

# Plot the data
plt.figure(figsize=(12, 8))

for cycle_numbers, discharge_capacities, cell_name in cells_data:
    plt.plot(cycle_numbers, discharge_capacities, label=cell_name, marker='o', linestyle='-')

plt.xlabel('Cycle Number')
plt.ylabel('Discharge Capacity (A.h)')
plt.title('Cycle Number vs Average Discharge Capacity for Each Cell')
plt.legend()
plt.grid(True)
plt.ylim(0, max(data[discharge_capacity_column]) / 1000)  # Adjust y-axis limits if needed
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file, skipping the first 98 rows and using row 99 as the header
file_path =  'C:\\Users\\harshitha\\Desktop\\batteryml\\BatteryML-main\\BatteryML-main\\Custom data.xlsx'
data = pd.read_excel(file_path, skiprows=98)

# Check the columns in the DataFrame
data.columns = data.columns.str.strip()
print("Columns in the dataset:", data.columns)

# Specify the columns of interest
ns_column = 'Ns'
cycle_number_column = 'cycle number'
discharge_capacity_column = 'Q discharge/mA.h'

# Print initial rows of the dataset
print("Initial data (first 5 rows):")
print(data.head())

# Filter out rows with NaN values in critical columns and rows with zero discharge capacity
data = data.dropna(subset=[ns_column, cycle_number_column, discharge_capacity_column])
data = data[data[discharge_capacity_column] > 0]

# Print rows after filtering
print("Data after filtering (first 5 rows):")
print(data.head())

# Print unique values in the 'Ns' column to see which cells are present
unique_cells = data[ns_column].unique()
print("Unique cells present in the dataset:", unique_cells)

# List to store data for each cell
cells_data = []

# Extract data for each cell based on 'Ns' column and calculate average discharge capacity for each cycle
for cell_num in unique_cells:
    cell_data = data[data[ns_column] == cell_num]
    if not cell_data.empty:
        print(f"Cell {cell_num} data (first 5 rows):\n", cell_data[[cycle_number_column, discharge_capacity_column]].head())
        avg_discharge_per_cycle = cell_data.groupby(cycle_number_column)[discharge_capacity_column].mean() / 1000  # Convert to A.h
        cycle_numbers = avg_discharge_per_cycle.index
        discharge_capacities = avg_discharge_per_cycle.values
        cells_data.append((cycle_numbers, discharge_capacities, f'Cell {int(cell_num)}'))
    else:
        print(f"Cell {int(cell_num)} has no data")

# Plot the data
plt.figure(figsize=(12, 8))

for cycle_numbers, discharge_capacities, cell_name in cells_data:
    plt.plot(cycle_numbers, discharge_capacities, label=cell_name, marker='o', linestyle='-')

plt.xlabel('Cycle Number')
plt.ylabel('Discharge Capacity (A.h)')
plt.title('Cycle Number vs Average Discharge Capacity for Each Cell')
plt.legend()
plt.grid(True)
plt.ylim(0, max(data[discharge_capacity_column]) / 1000)  # Adjust y-axis limits if needed
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file, skipping the first 98 rows and using row 99 as the header
file_path =  'C:\\Users\\harshitha\\Desktop\\batteryml\\BatteryML-main\\BatteryML-main\\Custom data.xlsx'
data = pd.read_excel(file_path, skiprows=98)

# Check the columns in the DataFrame
data.columns = data.columns.str.strip()
print("Columns in the dataset:", data.columns)

# Specify the columns of interest
ns_column = 'Ns'
cycle_number_column = 'cycle number'
discharge_capacity_column = 'Q discharge/mA.h'

# Print initial rows of the dataset
print("Initial data (first 5 rows):")
print(data.head())

# List to store data for each cell
cells_data = []

# Extract data for each cell based on 'Ns' column and calculate average discharge capacity for each cycle
unique_cells = data[ns_column].unique()
print("Unique cells present in the dataset:", unique_cells)

for cell_num in unique_cells:
    cell_data = data[data[ns_column] == cell_num]
    if not cell_data.empty:
        print(f"Cell {int(cell_num)} data (first 5 rows):\n", cell_data[[cycle_number_column, discharge_capacity_column]].head())
        avg_discharge_per_cycle = cell_data.groupby(cycle_number_column)[discharge_capacity_column].mean() / 1000  # Convert to A.h
        cycle_numbers = avg_discharge_per_cycle.index
        discharge_capacities = avg_discharge_per_cycle.values
        cells_data.append((cycle_numbers, discharge_capacities, f'Cell {int(cell_num)}'))
    else:
        print(f"Cell {int(cell_num)} has no data")

# Plot the data
plt.figure(figsize=(12, 8))

for cycle_numbers, discharge_capacities, cell_name in cells_data:
    plt.plot(cycle_numbers, discharge_capacities, label=cell_name, marker='o', linestyle='-')

plt.xlabel('Cycle Number')
plt.ylabel('Discharge Capacity (A.h)')
plt.title('Cycle Number vs Average Discharge Capacity for Each Cell')
plt.legend()
plt.grid(True)
plt.ylim(0, max(data[discharge_capacity_column]) / 1000)  # Adjust y-axis limits if needed
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file, skipping the first 98 rows and using row 99 as the header
file_path = 'C:\\Users\\harshitha\\Desktop\\batteryml\\BatteryML-main\\BatteryML-main\\Custom data.xlsx'
data = pd.read_excel(file_path, skiprows=98)

# Strip any leading/trailing whitespace from column names
data.columns = data.columns.str.strip()

# Columns of interest
ns_column = 'Ns'
cycle_number_column = 'cycle number'
discharge_capacity_column = 'Q discharge/mA.h'

# List to store data for each cell
cells_data = []

# Extract data for each cell based on 'Ns' column and calculate average discharge capacity for each cycle
for cell_num in range(1, 11):
    cell_data = data[data[ns_column] == cell_num]
    if not cell_data.empty:
        avg_discharge_per_cycle = cell_data.groupby(cycle_number_column)[discharge_capacity_column].mean() / 1000  # Convert to A.h
        cycle_numbers = avg_discharge_per_cycle.index
        discharge_capacities = avg_discharge_per_cycle.values
        cells_data.append((cycle_numbers, discharge_capacities, f'Cell {cell_num}'))

# Plot the data
plt.figure(figsize=(12, 8))

for cycle_numbers, discharge_capacities, cell_name in cells_data:
    plt.plot(cycle_numbers, discharge_capacities, label=cell_name, marker='o', linestyle='-')

plt.xlabel('Cycle Number')
plt.ylabel('Discharge Capacity (A.h)')
plt.title('Cycle Number vs Average Discharge Capacity for Each Cell')
plt.legend()
plt.grid(True)
plt.ylim(0, max(data[discharge_capacity_column]) / 1000)  # Adjust y-axis limits if needed
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file, skipping the first 98 rows and using row 99 as the header
file_path = 'C:\\Users\\harshitha\\Desktop\\batteryml\\BatteryML-main\\BatteryML-main\\Custom data.xlsx'
data = pd.read_excel(file_path, skiprows=98)

# Strip any leading/trailing whitespace from column names
data.columns = data.columns.str.strip()

# Columns of interest
ns_column = 'Ns'
cycle_number_column = 'cycle number'
capacity_column = 'Capacity/mA.h'  # Assuming this is the capacity column

# List to store data for each cell
cells_data = []

# Extract data for each cell based on 'Ns' column and calculate average capacity for each cycle
for cell_num in range(1, 11):
    cell_data = data[data[ns_column] == cell_num]
    if not cell_data.empty:
        avg_capacity_per_cycle = cell_data.groupby(cycle_number_column)[capacity_column].mean() / 1000  # Convert to A.h
        cycle_numbers = avg_capacity_per_cycle.index
        capacities = avg_capacity_per_cycle.values
        cells_data.append((cycle_numbers, capacities, f'Cell {cell_num}'))

# Plot the data
plt.figure(figsize=(12, 8))

for cycle_numbers, capacities, cell_name in cells_data:
    plt.plot(cycle_numbers, capacities, label=cell_name, marker='o', linestyle='-')

plt.xlabel('Cycle Number')
plt.ylabel('Capacity (A.h)')
plt.title('Cycle Number vs Average Capacity for Each Cell')
plt.legend()
plt.grid(True)
plt.ylim(0, max(data[capacity_column]) / 1000)  # Adjust y-axis limits if needed
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file, skipping the first 98 rows and using row 99 as the header
file_path = 'C:\\Users\\harshitha\\Desktop\\batteryml\\BatteryML-main\\BatteryML-main\\Custom data.xlsx'
data = pd.read_excel(file_path, skiprows=98)

# Strip any leading/trailing whitespace from column names
data.columns = data.columns.str.strip()

# Columns of interest
ns_column = 'Ns'
cycle_number_column = 'cycle number'
capacity_column = 'Capacity/mA.h'  # Assuming this is the capacity column

# List to store data for each cell
cells_data = []

# Iterate over unique cells and calculate average capacity for each cycle
unique_cells = data[ns_column].unique()
for cell_num in unique_cells:
    cell_data = data[data[ns_column] == cell_num]
    if not cell_data.empty:
        avg_capacity_per_cycle = cell_data.groupby(cycle_number_column)[capacity_column].mean() / 1000  # Convert to A.h
        cycle_numbers = avg_capacity_per_cycle.index
        capacities = avg_capacity_per_cycle.values
        cells_data.append((cycle_numbers, capacities, f'Cell {cell_num}'))

        # Print average capacity data for each cell
        print(f"Cell {cell_num}:")
        for cycle, capacity in zip(cycle_numbers, capacities):
            print(f"  Cycle {cycle}: Average Capacity = {capacity:.2f} A.h")

# Plot the data
plt.figure(figsize=(12, 8))

for cycle_numbers, capacities, cell_name in cells_data:
    plt.plot(cycle_numbers, capacities, label=cell_name, marker='o', linestyle='-')

plt.xlabel('Cycle Number')
plt.ylabel('Capacity (A.h)')
plt.title('Cycle Number vs Average Capacity for Each Cell')
plt.legend()
plt.grid(True)
plt.ylim(0, max(data[capacity_column]) / 1000)  # Adjust y-axis limits if needed
plt.show()

# %%
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result
from batteryml.preprocess.preprocess_Custom import CustomPreprocessor
from sklearn.model_selection import train_test_split
from pathlib import Path

# Step 1: Process data and split into train/test
preprocessor = CustomPreprocessor(output_dir='C:/Users/harshitha/Desktop/batteryml/BatteryML-main/BatteryML-main/processed_data/Custom', silent=False)
excel_path = 'C:/Users/harshitha/Desktop/batteryml/BatteryML-main/BatteryML-main/Custom data.xlsx'
batteries = preprocessor.process(excel_path)
train_batteries, test_batteries = train_test_split(batteries, test_size=0.2, random_state=42)

# Step 2: Configure and train the pipeline
pipeline = Pipeline(config_path='configs/baselines/sklearn/discharge_model/matr_1.yaml', workspace='workspaces')
model, dataset = pipeline.train(device='cpu', skip_if_executed=False, dataset=train_batteries)

# Step 3: Evaluate the trained model on test data
pipeline.evaluate(model=model, dataset=test_batteries, skip_if_executed=False)

# Step 4: Generate predictions on the test data
predictions = model.predict(test_batteries, data_type='test').to('cpu')

# Step 5: Plot results to visualize model performance
ground_truth = [battery.label for battery in test_batteries]
plot_result(ground_truth, predictions)

# %%
# Import necessary modules
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result

# Create a pipeline with a config file by specifying the config_path and workspace.
# Developers need to modify the data, feature, model and other related settings in the config file in advance.
pipeline = Pipeline(config_path='configs/baselines/sklearn/discharge_model/custom.yaml', workspace='workspaces')

# Model training. The training process will follow the config file, and the checkpoints will be saved to workspace.
model, dataset = pipeline.train(device='cpu', skip_if_executed=False)

# Evaluate the trained model on the given dataset.
pipeline.evaluate(model=model, dataset=dataset, skip_if_executed=False)

# Generate predictions on the test data.
prediction = model.predict(dataset, data_type='test').to('cpu')

# Extract ground truth labels for the test data.
ground_truth = dataset.test_data.label.to('cpu')

# Plot the results to visualize model performance.
plot_result(ground_truth, prediction)

# %%
# Import necessary modules
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result

# Create a pipeline with a config file by specifying the config_path and workspace.
# Developers need to modify the data, feature, model and other related settings in the config file in advance.
pipeline = Pipeline(config_path='configs/baselines/sklearn/variance_model/custom.yaml', workspace='workspaces')

# Model training. The training process will follow the config file, and the checkpoints will be saved to workspace.
model, dataset = pipeline.train(device='cpu', skip_if_executed=False)

# Evaluate the trained model on the given dataset.
pipeline.evaluate(model=model, dataset=dataset, skip_if_executed=False)

# Generate predictions on the test data.
prediction = model.predict(dataset, data_type='test').to('cpu')

# Extract ground truth labels for the test data.
ground_truth = dataset.test_data.label.to('cpu')

# Plot the results to visualize model performance.
plot_result(ground_truth, prediction)

# %%
import pickle

# Load predictions from the pickle file
with open('C:/Users/harshitha/Desktop/batteryml/BatteryML-main/BatteryML-main/processed_data/MATR_b1c0.pkl', 'rb') as f:
    data = pickle.load(f)
print(data.keys())
print(type(data['cell_id'])

# %%
print(len(data))

# %%
for i in data.values():
    print(type(i))

# %%
print(len(data['discharge_protocol']))

# %%
# Import necessary modules
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result

# Create a pipeline with a config file by specifying the config_path and workspace.
# Developers need to modify the data, feature, model and other related settings in the config file in advance.
pipeline = Pipeline(config_path='configs/baselines/sklearn/rf/matr_1.yaml', workspace='workspaces')

# Model training. The training process will follow the config file, and the checkpoints will be saved to workspace.
model, dataset = pipeline.train(device='cpu', skip_if_executed=False)

# Evaluate the trained model on the given dataset.
pipeline.evaluate(model=model, dataset=dataset, skip_if_executed=False)

# Generate predictions on the test data.
prediction = model.predict(dataset, data_type='test').to('cpu')

# Extract ground truth labels for the test data.
ground_truth = dataset.test_data.label.to('cpu')

# Plot the results to visualize model performance.
plot_result(ground_truth, prediction)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the path to your file
file_path = r"C:\Users\harshitha\Downloads\Low Temperature\-20Celsius 0.375C charge and discharge\20 cycles\20 cycles at -20\2406170002patricio_CB1.mpt"

# Read the data, trying with a different encoding if UTF-8 fails
try:
    df = pd.read_csv(file_path, skiprows=99, delimiter='\t', encoding='latin1')  # Adjust delimiter if needed
except UnicodeDecodeError:
    df = pd.read_csv(file_path, skiprows=99, delimiter='\t', encoding='ISO-8859-1')  # Another common encoding

# Display the first few rows to understand the structure
print(df.head())

# Extract the cycle number and discharge capacity columns
# Replace 'cycle number' and 'Capacity/mA.h' with the actual column names from your dataset
cycle_numbers = df['cycle number']
discharge_capacity = df['Q discharge/mA.h']

# Plotting the graph
plt.figure(figsize=(10, 6))
plt.plot(cycle_numbers, discharge_capacity, label='Discharge Capacity')
plt.xlabel('Cycle Number')
plt.ylabel('Discharge Capacity (mA.h)')
plt.title('Cycle Number vs. Discharge Capacity')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the path to your file
file_path = r"C:\Users\harshitha\Downloads\Low Temperature\-20Celsius 0.375C charge and discharge\20 cycles\20 cycles at -20\2406170002patricio_CB1.mpt"

# Read the data, trying with a different encoding if UTF-8 fails
try:
    df = pd.read_csv(file_path, skiprows=98, delimiter='\t', encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(file_path, skiprows=98, delimiter='\t', encoding='ISO-8859-1')

# Display the first few rows and the column names to understand the structure
print(df.head())
print("\nColumn Names:\n", df.columns)

# Extract the cycle number and discharge capacity columns
# Replace 'actual_cycle_number_column_name' and 'actual_discharge_capacity_column_name' with the actual column names from your dataset
cycle_numbers = df['cycle number']
discharge_capacity = df['Q discharge/mA.h']

# Plotting the graph
plt.figure(figsize=(10, 6))
plt.plot(cycle_numbers, discharge_capacity, label='Discharge Capacity')
plt.xlabel('Cycle Number')
plt.ylabel('Discharge Capacity (mA.h)')
plt.title('Cycle Number vs. Discharge Capacity')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd

# File path to your Excel file
file_path = r"C:\Users\harshitha\Desktop\Channel A1.xlsx"

# Number of rows to skip
skiprows = 98

# Read the Excel file and print columns
df = pd.read_excel(file_path, skiprows=skiprows)

# Print the column names
print("Columns in the dataset:")
print(df.columns)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# File path to your Excel file
file_path = r"C:\Users\harshitha\Desktop\Channel A1.xlsx"

# Number of rows to skip (adjust as needed)
skiprows = 98

# Read the Excel file
df = pd.read_excel(file_path, skiprows=skiprows)

# Select cycle number and discharge capacity columns
cycle_discharge_data = df[['cycle number', 'Q discharge/mA.h']]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(cycle_discharge_data['cycle number'], cycle_discharge_data['Q discharge/mA.h'], marker='o', linestyle='-')
plt.title('Discharge Capacity vs Cycle Number')
plt.xlabel('Cycle Number')
plt.ylabel('Discharge Capacity (mA.h)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# File path to your Excel file
file_path = r"C:\Users\harshitha\Desktop\Channel A1.xlsx"

# Number of rows to skip (adjust as needed)
skiprows = 98

# Read the Excel file
df = pd.read_excel(file_path, skiprows=skiprows)

# Group by 'cycle number' and find the maximum 'Q discharge/mA.h' for each cycle number
max_discharge_capacity = df.groupby('cycle number')['Q discharge/mA.h'].max().reset_index()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(max_discharge_capacity['cycle number'], max_discharge_capacity['Q discharge/mA.h'], marker='o', linestyle='-')
plt.title('Maximum Discharge Capacity vs Cycle Number')
plt.xlabel('Cycle Number')
plt.ylabel('Maximum Discharge Capacity (mA.h)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Directory containing the Excel files
folder_path = r"C:\Users\harshitha\Desktop\dataset custom"

# Initialize an empty list to store all max discharge capacity dataframes
all_max_capacity_dfs = []

# Iterate through each file in the folder
for file in os.listdir(folder_path):
    if file.endswith(".xlsx"):
        file_path = os.path.join(folder_path, file)
        # Read the Excel file, skipping rows as needed
        df = pd.read_excel(file_path, skiprows=98)
        # Group by 'cycle number' and find the maximum 'Q discharge/mA.h' for each cycle number
        max_discharge_capacity = df.groupby('cycle number')['Q discharge/mA.h'].max().reset_index()
        # Add the max discharge capacity dataframe to the list
        all_max_capacity_dfs.append(max_discharge_capacity)

# Plotting all data on the same graph
plt.figure(figsize=(10, 6))
for df, file in zip(all_max_capacity_dfs, os.listdir(folder_path)):
    if file.endswith(".xlsx"):
        plt.plot(df['cycle number'], df['Q discharge/mA.h'], marker='o', linestyle='-', label=f"{os.path.basename(file)}")

plt.title('Maximum Discharge Capacity vs Cycle Number for All Files')
plt.xlabel('Cycle Number')
plt.ylabel('Maximum Discharge Capacity (mA.h)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Directory containing the Excel files
folder_path = r"C:\Users\harshitha\Desktop\dataset custom"

# Initialize an empty list to store all max discharge capacity dataframes
all_max_capacity_dfs = []

# Iterate through each file in the folder
for file in os.listdir(folder_path):
    if file.endswith(".xlsx"):
        file_path = os.path.join(folder_path, file)
        # Read the Excel file, skipping rows as needed
        df = pd.read_excel(file_path, skiprows=98)
        # Group by 'cycle number' and find the maximum 'Q discharge/mA.h' for each cycle number
        max_discharge_capacity = df.groupby('cycle number')['Q discharge/mA.h'].max().reset_index()
        # Add the max discharge capacity dataframe to the list
        all_max_capacity_dfs.append((os.path.basename(file), max_discharge_capacity))

# Plotting all data on the same graph
plt.figure(figsize=(12, 8))  # Increase figure size for better visibility
for filename, df in all_max_capacity_dfs:
    plt.plot(df['cycle number'], df['Q discharge/mA.h'], marker='o', linestyle='-', label=filename)

plt.title('Maximum Discharge Capacity vs Cycle Number for All Files')
plt.xlabel('Cycle Number')
plt.ylabel('Maximum Discharge Capacity (mA.h)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Directory containing the Excel files
folder_path = r"C:\Users\harshitha\Desktop\dataset custom"

# Initialize an empty list to store all average discharge capacity dataframes
all_avg_capacity_dfs = []

# Iterate through each file in the folder
for file in os.listdir(folder_path):
    if file.endswith(".xlsx"):
        file_path = os.path.join(folder_path, file)
        # Read the Excel file, skipping rows as needed
        df = pd.read_excel(file_path, skiprows=98)
        # Group by 'cycle number' and calculate the average 'Q discharge/mA.h' for each cycle number
        avg_discharge_capacity = df.groupby('cycle number')['Q discharge/mA.h'].mean().reset_index()
        # Add the average discharge capacity dataframe to the list
        all_avg_capacity_dfs.append((os.path.basename(file), avg_discharge_capacity))

# Plotting all data on the same graph
plt.figure(figsize=(12, 8))  # Increase figure size for better visibility
for filename, df in all_avg_capacity_dfs:
    plt.plot(df['cycle number'], df['Q discharge/mA.h'], marker='o', linestyle='-', label=filename)

plt.title('Average Discharge Capacity vs Cycle Number for All cells')
plt.xlabel('Cycle Number')
plt.ylabel('Average Discharge Capacity (mA.h)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result
from batteryml.preprocess.preprocess_Custom import CustomPreprocessor
# from batteryml.train_test_split.splitter import TRAIN_TEST_SPLITTERS
from pathlib import Path

# Register the custom train-test splitter
from batteryml.train_test_split import CustomTrainTestSplitter

# Step 1: Process data and split into train/test using CustomPreprocessor and CustomTrainTestSplitter
preprocessor = CustomPreprocessor(output_dir='C:/Users/harshitha/Desktop/batteryml/BatteryML-main/BatteryML-main/processed_data/Custom', silent=False)
excel_path = 'C:/Users/harshitha/Desktop/dataset custom'
batteries = preprocessor.process(excel_path)
train_batteries, test_batteries = CustomTrainTestSplitter(excel_path).split()

# Step 2: Configure and train the pipeline
pipeline = Pipeline(config_path='configs/baselines/sklearn/discharge_model/custom.yaml', workspace='workspaces')
model, dataset = pipeline.train(device='cpu', skip_if_executed=False, dataset=train_batteries)

# Step 3: Evaluate the trained model on test data
pipeline.evaluate(model=model, dataset=test_batteries, skip_if_executed=False)

# Step 4: Generate predictions on the test data
predictions = model.predict(test_batteries, data_type='test').to('cpu')

# Step 5: Plot results to visualize model performance
ground_truth = [battery.label for battery in test_batteries]
plot_result(ground_truth, predictions)

# %%
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result
from batteryml.preprocess.preprocess_Custom import CustomPreprocessor
# from batteryml.train_test_split.splitter import TRAIN_TEST_SPLITTERS
from pathlib import Path

# Register the custom train-test splitter
from batteryml.train_test_split import CustomTrainTestSplitter

# Step 1: Process data and split into train/test using CustomPreprocessor and CustomTrainTestSplitter
preprocessor = CustomPreprocessor(output_dir='C:/Users/harshitha/Desktop/batteryml/BatteryML-main/BatteryML-main/processed_data/Custom', silent=False)
excel_path = 'C:/Users/harshitha/Desktop/dataset custom'
batteries = preprocessor.process(excel_path)
train_batteries, test_batteries = CustomTrainTestSplitter(excel_path).split()

# Step 2: Configure and train the pipeline
pipeline = Pipeline(config_path='configs/baselines/sklearn/discharge_model/custom.yaml', workspace='workspaces')
model, dataset = pipeline.train(device='cpu', skip_if_executed=False, dataset=train_batteries)

# Step 3: Evaluate the trained model on test data
pipeline.evaluate(model=model, dataset=test_batteries, skip_if_executed=False)

# Step 4: Generate predictions on the test data
predictions = model.predict(test_batteries, data_type='test').to('cpu')

# Step 5: Plot results to visualize model performance
ground_truth = [battery.label for battery in test_batteries]
plot_result(ground_truth, predictions)

# %%
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result
from batteryml.preprocess.preprocess_Custom import CustomPreprocessor
# from batteryml.train_test_split.splitter import TRAIN_TEST_SPLITTERS
from pathlib import Path

# Register the custom train-test splitter
from batteryml.train_test_split import CustomTrainTestSplitter

# Step 1: Process data and split into train/test using CustomPreprocessor and CustomTrainTestSplitter
preprocessor = CustomPreprocessor(output_dir='C:/Users/rishi/Desktop/batteryml/BatteryML-main/BatteryML-main/processed_data/Custom', silent=False)
excel_path = 'C:/Users/rishi/Desktop/dataset custom'
batteries = preprocessor.process(excel_path)

# %%
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result
from batteryml.preprocess.preprocess_Custom import CustomPreprocessor
from batteryml.train_test_split import CustomTrainTestSplitter
from pathlib import Path
processed_path = r"C:\Users\harshitha\Desktop\batteryml\BatteryML-main\BatteryML-main\processed_data\Custom"
train_batteries, test_batteries = CustomTrainTestSplitter(processed_path).split()

# Step 2: Configure and train the pipeline
pipeline = Pipeline(config_path='configs/baselines/sklearn/discharge_model/custom.yaml', workspace='workspaces')
model, dataset = pipeline.train(device='cpu', skip_if_executed=False, dataset=train_batteries)

# Step 3: Evaluate the trained model on test data
pipeline.evaluate(model=model, dataset=test_batteries, skip_if_executed=False)

# Step 4: Generate predictions on the test data
predictions = model.predict(test_batteries, data_type='test').to('cpu')

# Step 5: Plot results to visualize model performance
ground_truth = [battery.label for battery in test_batteries]
plot_result(ground_truth, predictions)

# %%
# Import necessary modules
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result

# Create a pipeline with a config file by specifying the config_path and workspace.
# Developers need to modify the data, feature, model and other related settings in the config file in advance.
pipeline = Pipeline(config_path='configs/baselines/sklearn/discharge_model/custom.yaml', workspace='workspaces')
print(pipeline)

# Model training. The training process will follow the config file, and the checkpoints will be saved to workspace.
model, dataset = pipeline.train(device='cpu', skip_if_executed=False)

# Evaluate the trained model on the given dataset.
pipeline.evaluate(model=model, dataset=dataset, skip_if_executed=False)

# Generate predictions on the test data.
prediction = model.predict(dataset, data_type='test').to('cpu')

# Extract ground truth labels for the test data.
ground_truth = dataset.test_data.label.to('cpu')

# Plot the results to visualize model performance.
plot_result(ground_truth, prediction)

# %%
# Import necessary modules
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_result

# Create a pipeline with a config file by specifying the config_path and workspace.
# Developers need to modify the data, feature, model and other related settings in the config file in advance.
pipeline = Pipeline(config_path='configs/baselines/sklearn/discharge_model/matr_1.yaml', workspace='workspaces')
print(pipeline)

# Model training. The training process will follow the config file, and the checkpoints will be saved to workspace.
model, dataset = pipeline.train(device='cpu', skip_if_executed=False)

# Evaluate the trained model on the given dataset.
pipeline.evaluate(model=model, dataset=dataset, skip_if_executed=False)

# Generate predictions on the test data.
prediction = model.predict(dataset, data_type='test').to('cpu')

# Extract ground truth labels for the test data.
ground_truth = dataset.test_data.label.to('cpu')

# Plot the results to visualize model performance.
plot_result(ground_truth, prediction)
